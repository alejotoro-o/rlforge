# %%
import numpy as np
import matplotlib.pyplot as plt

import gymnasium as gym

from rlforge.experiments import runEpisodicExperiment
from rlforge.agents.semi_gradient import LinearQAgent

# %%
env = gym.make("MountainCar-v0")
agent = LinearQAgent(step_size=0.5/8,
                     discount=1,
                     num_actions=env.action_space.n,
                     dims_ranges=((-1.2,0.6),(-0.07,0.07)),
                     epsilon=0.1,
                     iht_size=4096,
                     num_tilings=8,
                     num_tiles=8)

# %%
rewards, steps_per_episode = runEpisodicExperiment(env, agent, 10, 50, 10000)
# Out:
# Run 0/10 - Episodes:   0%|          | 0/50 [00:00<?, ?it/s]

# %%
plt.plot(np.mean(rewards, axis=1))
plt.grid()

# %%
plt.plot(np.mean(steps_per_episode, axis=1))
plt.grid()
